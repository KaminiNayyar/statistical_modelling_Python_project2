# %%
import requests
import pandas as pd
import json

# %%
url = 'http://api.citybik.es/v2/networks' 
headers = {"Accept": "application/json"} 
ct_byk_result = requests.get(url, headers=headers).json()
ct_byk_result['networks']
# Out:
# [{'company': ['ЗАО «СитиБайк»'],
#   'href': '/v2/networks/velobike-moscow',
#   'id': 'velobike-moscow',
#   'location': {'city': 'Moscow',
#    'country': 'RU',
#    'latitude': 55.75,
#    'longitude': 37.616667},
#   'name': 'Velobike'},
#  {'company': ['Urban Infrastructure Partner'],
#   'href': '/v2/networks/baerum-bysykkel',
#   'id': 'baerum-bysykkel',
#   'location': {'city': 'Bærum',
#    'country': 'NO',
#    'latitude': 59.89455,
#    'longitude': 10.546343},
#   'name': 'Bysykkel'},
#  {'company': ['Comunicare S.r.l.'],
#   'href': '/v2/networks/bicincitta-siena',
#   'id': 'bicincitta-siena',
#   'location': {'city': 'Siena',
#    'country': 'IT',
#    'latitude': 43.3186,
#    'longitude': 11.3306},
#   'name': 'Bicincittà',
#   'source': 'https://www.bicincitta.com/frmLeStazioni.aspx?ID=202'},
#  {'company': ['Cyclopolis Systems'],
#   'href': '/v2/networks/cyclopolis-maroussi',
#   'id': 'cyclopolis-maroussi',
#   'location': {'city': 'Maroussi',
# ...

# %%
print(len(ct_byk_result['networks']))

# checking for countries details in the result
for i in range(614):
    print(ct_byk_result['networks'][i]['location']['country'])
# Out:
# 614
# RU
# NO
# IT
# GR
# GB
# GR
# IT
# GR
# GR
# IT
# GR
# GR
# GR
# GR
# IT
# GR
# GR
# IT
# GR
# IT
# IT
# IT
# IE
# IE
# TH
# IE
# PL
# IT
# PL
# GB
# US
# IT
# IS
# DE
# IT
# IT
# KZ
# FR
# IT
# IT
# ES
# IT
# IT
# IT
# IT
# ES
# MX
# IT
# BE
# IT
# SE
# CL
# ES
# GR
# IT
# GR
# GR
# IT
# GR
# GR
# IT
# GR
# GR
# GR
# GR
# IT
# GR
# GR
# IT
# CY
# GR
# GR
# GR
# GR
# IT
# BR
# ES
# ES
# AU
# AU
# IT
# CA
# IT
# CA
# CA
# US
# IT
# IT
# US
# US
# IT
# IT
# US
# IT
# US
# US
# US
# US
# IT
# US
# US
# US
# US
# US
# IT
# US
# IT
# US
# US
# IT
# US
# US
# US
# IT
# US
# US
# IT
# US
# US
# US
# US
# US
# US
# IT
# US
# US
# US
# IT
# US
# US
# US
# US
# US
# US
# IT
# US
# US
# IT
# US
# US
# US
# IT
# US
# US
# BR
# BR
# BR
# BR
# BR
# MX
# UK
# AU
# FR
# CL
# NO
# NO
# NO
# FR
# FR
# FR
# FR
# ES
# ES
# ES
# IT
# ES
# ES
# ES
# ES
# IT
# AR
# PT
# IT
# FR
# FR
# LU
# ES
# IT
# SE
# SE
# IT
# ES
# FR
# NO
# FR
# IT
# FR
# SI
# IT
# ES
# IT
# BE
# FR
# FR
# BE
# IT
# FR
# LT
# ...

# %% [markdown]
# ## Chose US

# %%
ct_byk = len(ct_byk_result['networks'])
ct_byk

# checking for country USA details in the result
us_ct_byk = []
for i in range(ct_byk):
    if ct_byk_result['networks'][i]['location']['country'] == "US":
         us_ct_byk.append(ct_byk_result['networks'][i])

print(len(us_ct_byk))
for i in range(52):
    print(us_ct_byk[i]['location']['city'])
# Out:
# 52
# Aspen, CO
# Ann Arbor, MI
# Austin, TX
# Chattanooga, TN
# Portland, OR
# San Ramon, CA
# Boise, ID
# Boulder, CO
# Santa Monica, CA
# Fort Lauderdale, FL
# Milwaukee, WI
# Buffalo, NY
# Washington, DC
# Charlotte, NC
# Cincinnati, OH
# New York, NY
# Tampa, FL
# Columbus, OH
# Denver, CO
# Chicago, IL
# El Paso, TX
# Fort Worth, TX
# Fargo, ND
# Salt Lake City
# Phoenix, AZ
# Omaha, NE
# Houston, TX
# Boston, MA
# Philadelphia, PA
# Indianapolis, IN
# Orlando, FL
# Kansas City, MO
# Dayton, OH
# Madison, WI
# Los Angeles, CA
# Ketchum / Sun Valley, ID
# Minneapolis, MN
# San Antonio, TX
# University of South Florida, FL
# Long Beach, NY
# Spartanburg, SC
# Topeka, KS
# University of Virginia, VA
# Atlanta, GA
# Miami Beach, FL
# San Diego, CA
# Des Moines, IA
# Greenville, SC
# Pittsburgh
# San Francisco Bay Area, CA
# Las Vegas, NV
# Oklahoma, OK

# %% [markdown]
# ## Chose city Boston, MA

# %%
ct_byk_boston = []
for i in range(52):
    if us_ct_byk[i]['location']['city'] == "Boston, MA":
        ct_byk_boston.append(us_ct_byk[i])
ct_byk_boston    
print(len(ct_byk_boston))
# Out:
# 1

# %%
boston_byks = ct_byk_boston[0]['href']
url = f'https://api.citybik.es{boston_byks}'
boston_byk_stations = requests.get(url).json()['network']['stations']
print(len(boston_byk_stations))
boston_byk_stations[50]
# Out:
# 386
# {'empty_slots': 20,
#  'extra': {'ebikes': 0,
#   'has_ebikes': True,
#   'last_updated': 1672865591,
#   'payment': ['creditcard', 'key'],
#   'payment-terminal': True,
#   'renting': 1,
#   'returning': 1,
#   'slots': 53,
#   'uid': '179'},
#  'free_bikes': 32,
#  'id': '943a5046e94d9462496182d9e38da371',
#  'latitude': 42.355601213279265,
#  'longitude': -71.10394477844238,
#  'name': 'MIT Vassar St',
#  'timestamp': '2023-01-04T21:05:54.574000Z'}

# %%
def boston_bykstations_name(station_name):
    boston_byk_stations = {'name': i['name'], 'latitude': i['latitude'],        'longitude' : i['longitude'], 
                          'id' : i['id'], 'free_bikes': i['free_bikes'], 'ebikes': i['extra']['ebikes'],
                          'normal_bikes': i['extra']['normal_bikes'],'slots': i['slots']}
                                                                                                                                                                                                                                                                                                        
BostonDF = pd.DataFrame(boston_byk_stations)
BostonDF['ll'] = moscowDF['latitude'].astype(str) + ' ' + BostonDF['longitude'].astype(str)
BostonDF.head(1)
# Out:
#    empty_slots                                              extra  free_bikes  \
# 0            1  {'ebikes': 0, 'has_ebikes': True, 'last_update...          18
#
#                                  id   latitude  longitude  \
# 0  553ed0300d38108b4f21a6bafa3db70c  42.386781 -71.006098
#
#                                                 name  \
# 0  Orient Heights T Stop - Bennington St at Sarat...
#
#                      timestamp                    ll
# 0  2023-01-04T21:05:54.684000Z  42.386781 -71.006098

# %% [markdown]
# # Parsed into the dataframe

# %%
BostonDF = pd.DataFrame(moscow_byk_stations)
BostonDF
# Out:
#      empty_slots                                              extra  \
# 0              1  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 1             20  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 2              2  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 3              4  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 4              6  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# ..           ...                                                ...
# 381           14  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 382           15  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 383            7  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 384           17  {'ebikes': 0, 'has_ebikes': True, 'last_update...
# 385           22  {'ebikes': 0, 'has_ebikes': True, 'last_update...
#
#      free_bikes                                id   latitude  longitude  \
# 0            18  553ed0300d38108b4f21a6bafa3db70c  42.386781 -71.006098
# ...

# %% [markdown]
# # Test - Saving the file in th system and extracting lat and long from the desired city (Boston)

# %%
BostonDF.to_csv(f'/Users/kamininayyar/Github_old_pc/GitHub_frm_old_pc/BostonDF.csv', index = False)

# %%
ct_bks_df = pd.read_csv(f'/Users/kamininayyar/Github_old_pc/GitHub_frm_old_pc/BostonDF.csv')

# %%
lat = ct_bks_df['latitude']
long = ct_bks_df['longitude']
print(f'{lat[10]},{long[10]}')
# Out:
# 42.341332,-71.076847
